# %%
import smart_geocubes

# %%
adem_path = ""
accessor = smart_geocubes.ArcticDEM10m(adem_path, False)
adem = accessor.open_xarray()
adem

# %%
res = 1000

# %%
adem.dem.isel(x=slice(None, None, res), y=slice(None, None, res))

# %%
adem.dem.isel(x=slice(None, None, res), y=slice(None, None, res)).plot.imshow(
    figsize=(10, 10), cmap="terrain", vmin=-50, vmax=3000
)
